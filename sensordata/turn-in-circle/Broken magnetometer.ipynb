# %%
import pandas as pd 
import matplotlib.pyplot as plt

df = pd.read_csv(
    "magnetometer_2019_06_23_20_12_05.txt",
    usecols=["value_x", "value_y", "value_z"],
    delim_whitespace=True,
    skiprows=1)
print(df.to_string())

df.plot.line()
plt.show()

print("read some lines")
# for line in myfile:
#     print(line.strip())
# myfile.close()
# Out:
#         value_x    value_y     value_z
# 0    -22.931490 -34.484800  -49.780598
# 1    -23.272007 -34.891983  -49.406110
# 2    -23.675750 -35.139545  -50.235275
# 3    -23.363644 -34.962246  -51.395520
# 4    -23.522642 -34.748936  -50.864227
# 5    -23.775690 -34.533600  -50.149807
# 6    -23.517440 -35.332200  -50.145844
# 7    -23.358614 -35.540337  -50.521957
# 8    -23.486792 -35.169440  -51.377434
# 9    -23.427730 -34.776800  -51.823257
# 10   -23.645100 -34.976788  -51.466873
# 11   -23.703815 -35.379765  -51.331398
# 12   -23.614796 -34.803707  -52.388096
# 13   -23.709188 -34.791344  -51.894608
# 14   -23.522470 -34.754100  -51.019410
# 15   -23.493370 -34.544870  -50.854370
# 16   -23.371256 -34.306694  -49.941364
# 17   -23.471540 -33.690414  -49.545540
# 18   -23.781754 -33.924522  -50.092285
# 19   -23.745386 -34.360516  -51.071037
# 20   -23.681814 -34.530470  -50.177753
# 21   -23.906107 -34.095562  -48.987923
# 22   -23.688221 -33.911064  -49.809864
# ...
